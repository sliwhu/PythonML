# %% [markdown]
# CS50 Machine Learning--Image classifier

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x_train=np.array([[ 1,  1],
       [ 2,  2.5],
       [ 3, 1.2],
       [5.5, 6.3],
        [6, 9],
                 [7, 6]])
y_train=["red", "red", "red", "blue", "blue", "blue"]
x_train
# Out:
# array([[ 1. ,  1. ],
#        [ 2. ,  2.5],
#        [ 3. ,  1.2],
#        [ 5.5,  6.3],
#        [ 6. ,  9. ],
#        [ 7. ,  6. ]])

# %%
print (x_train[3][0])
print (x_train[3][1])
print (x_train[:, 1])
print (x_train[:, 0])
# Out:
# 5.5
# 6.3
# [ 1.   2.5  1.2  6.3  9.   6. ]
# [ 1.   2.   3.   5.5  6.   7. ]

# %%
plt.figure()
plt.scatter(x_train[:, 0], x_train[:, 1], s=170, color=y_train[:])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
x_test=np.array([3, 4])

# %%
plt.figure()
plt.scatter(x_train[:, 0], x_train[:, 1], s=170, color=y_train[:])
plt.scatter(x_test[0], x_test[1], s=170, color="green")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# To run the nearest neighbor classifier, define a distance function

# %%
def dist(x, y):
    return np.sqrt(np.sum((x-y)**2))

# %%
num=len(x_train)
distance=np.zeros(num)
for i in range (num):
    distance[i]=dist(x_train[i], x_test)
print (distance)
# Out:
# [ 3.60555128  1.80277564  2.8         3.39705755  5.83095189  4.47213595]

# %% [markdown]
# choose the point in x_train that is nearest to x_test

# %%
min_index=np.argmin(distance)
print (y_train[min_index])
# Out:
# red

# %% [markdown]
# Classifiying images

# %%
from sklearn import datasets
digits=datasets.load_digits()

# %%
print (digits.images[0])
# Out:
# [[  0.   0.   5.  13.   9.   1.   0.   0.]
#  [  0.   0.  13.  15.  10.  15.   5.   0.]
#  [  0.   3.  15.   2.   0.  11.   8.   0.]
#  [  0.   4.  12.   0.   0.   8.   8.   0.]
#  [  0.   5.   8.   0.   0.   9.   8.   0.]
#  [  0.   4.  11.   0.   1.  12.   7.   0.]
#  [  0.   2.  14.   5.  10.  12.   0.   0.]
#  [  0.   0.   6.  13.  10.   0.   0.   0.]]

# %%
plt.figure()
from matplotlib import cm
plt.imshow(digits.images[0], cmap=cm.gray_r, interpolation="nearest")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
x_train=digits.data[0:10]
y_train=digits.target[0:10]
x_test=digits.data[345]

# %%
plt.figure()
from matplotlib import cm
plt.imshow(digits.images[345],cmap=cm.gray_r, interpolation="nearest")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#run the nearest neighbor classifier
num=len(x_train)
distance=np.zeros(num)
for i in range (num):
    distance[i]=dist(x_train[i], x_test)
min_index=np.argmin(distance)
print(y_train[min_index])
# Out:
# 3

# %%
#test if the result is correct
print (digits.target[min_index])
# Out:
# 3

# %%
#number of mistakes done in testing 100 images
num=len(x_train)
No_errors=0
distance=np.zeros(num)
for j in range (1697, 1797):
    x_test=digits.data[j]
    for i in range (num):
        distance[i]=dist(x_train[i], x_test)
    min_index=np.argmin(distance)
    if y_train[min_index]!=digits.target[j]:
        No_errors +=1
print (No_errors)
# Out:
# 37

# %%
#improving the performance by increaseing training data sets size
x_train=digits.data[0:1000]
y_train=digits.target[0:1000]
num=len(x_train)
No_errors=0
distance=np.zeros(num)
for j in range(1697, 1797):
    x_test=digits.data[j]
    for i in range (num):
        distance[i]=dist(x_train[i], x_test)
    min_index=np.argmin(distance)
    if y_train[min_index]!=digits.target[j]:
        No_errors+=1
print (No_errors)
# Out:
# 3
